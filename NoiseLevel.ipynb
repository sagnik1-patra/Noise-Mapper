# %%
# !pip install prophet
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/13.3 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/13.3 MB 1.9 MB/s eta 0:00:07
#    --- ------------------------------------ 1.3/13.3 MB 1.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.3/13.3 MB 1.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.6/13.3 MB 1.3 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/13.3 MB 1.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.8/13.3 MB 1.2 MB/s eta 0:00:10
#    ------- -------------------------------- 2.4/13.3 MB 1.3 MB/s eta 0:00:09
#    ------- -------------------------------- 2.6/13.3 MB 1.3 MB/s eta 0:00:09
#    -------- ------------------------------- 2.9/13.3 MB 1.3 MB/s eta 0:00:09
# ...

# %%
import pandas as pd

# Replace with your CSV path
file_path = r"C:\Users\sagni\Downloads\Noise Mapper\noise_level_data.csv"

# Load CSV
try:
    noise_level_data = pd.read_csv(file_path)
except FileNotFoundError:
    raise FileNotFoundError(f"File not found: {file_path}")

# Show column names as a list
print("\n📌 Column names in the dataset:")
print(noise_level_data.columns.tolist())

# Show with repr to detect extra spaces or hidden characters
print("\n🔍 Column names with hidden characters visible:")
for col in noise_level_data.columns:
    print(repr(col))

# If you want to match a column ignoring spaces & case
search_key = "noise level"
matched_columns = [col for col in noise_level_data.columns if col.strip().lower() == search_key.lower()]

if matched_columns:
    print(f"\n✅ Found matching column: {matched_columns[0]}")
else:
    print(f"\n❌ No exact match found for '{search_key}' (ignoring case and spaces).")
# Out:
# 📌 Column names in the dataset:
# ['noise level ', 'label']
#
# 🔍 Column names with hidden characters visible:
# 'noise level '
# 'label'
#
# ✅ Found matching column: noise level
